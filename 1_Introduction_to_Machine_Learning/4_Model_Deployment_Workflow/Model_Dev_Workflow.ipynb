# %% [markdown]
# 1. [Introduction](https://www.youtube.com/watch?v=S-KI1qnOmCo)
#
# **Quiz Question**
#
# * Having a well-thought-out model deployment workflow allows for what in the future?
#   * Reproducing your work and iterating quickly.
#
# 2. [Lesson Outline](https://www.youtube.com/watch?v=zqBjS3NRQ3I)
# 3. [How Do Experts Think About Model Deployment Workflow?](https://www.youtube.com/watch?v=p3aJ3UDS4Jg)
# 4. [Dataset Principles](https://www.youtube.com/watch?v=3jOJA3WwVno)
# 5. [Solution: Dataset Principles](https://www.youtube.com/watch?v=gaPtenUSBV4)

# %% [markdown]
# **QUIZ QUESTION**
#
# In the exercise, we split the dataset to a proportion of 60/20/20, but why did we do this? What are some other reasonable splits?
#
# Splits will be in the form of train/validation/test.
# * 50/25/25
# * If the data is enough, we can split the data evenly. 33/33/33

# %% [markdown]
# 6. Data Cleansing and Feature Engineering
#
# * [Data Cleasing](https://www.youtube.com/watch?v=t2ZXT58uRl4)
# * [Feature Engineering](https://www.youtube.com/watch?v=DTx9PYzUK6U)
#
# 7. Data Cleansing
#
#
#
# 8. [Solution: Data Cleansing and Feature Engineering](https://www.youtube.com/watch?v=CKCqKECLt5A)
# 9. [Model Training](https://www.youtube.com/watch?v=YfzDm_TsOIM)
# 10. Quiz:Model Training
#
# Smaller datasets will always use less memory.
#
# While not as fast as memory, there are ways to store data on hard drives and use them during training.
#
# Going from a high precision datatype (float64) to a lower precision datatype (float16) can save on dataset size.
# 11. [Model Evaluation](https://www.youtube.com/watch?v=lN4spgiL9pw)
#
# Visit Scikit learn's [metric](https://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics) page for a good break down
# 12. [Solution: Model Training And Evaluation](https://www.youtube.com/watch?v=VGFy0lAzib8)
#
# In the exercise, we split the data into train, validation, and test sets, but do we always need to do that? And if so, why?
#
# - Depending on what you are doing with the model, you can get away with just having a train and test dataset. Among others, the reasons could be such as a lack of doing optimization or using small datasets.
#
#
# 13. [Hyperparameter Tuning](https://www.youtube.com/watch?v=24omKgs8gzA)
#
# **QUESTION 1 OF 2**
#
# For [Ridge regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html), which options in configuring the model would be hyperparameters?
# - max_iter
# - solver
# - alpha
#
# Select all that apply.
#
# **QUESTION 2 OF 2**
#
# At which point when building your ML model do you start focusing on tuning hyperparameters?
# - After you build and evaluate your model using the default settings, you can use the first model as a baseline and start tuning hyperparameters.
# - Correct! It is always good to start with a baseline using the easiest settings for a model. That way you can start optimizing afterward for comparison.
#
#
# 14. [When To Use Model Deployment Workflow](https://www.youtube.com/watch?v=U85qWlnl3Vw)
#
#
#
# 15. [Solution: Diabetes Model](https://www.youtube.com/watch?v=ncpG3XIDxPo)
#
# **QUIZ QUESTION**
#
# In the exercise, our R2 score for the model predicting our test dataset was lower than the train and validation dataset.
#
# Why is this the case?
# - The test dataset was held out from any training or hyperparameter tuning when we fit the model to the data, so the model is less likely to have been overfit.
# - The score is lower, but more representative of any future predictions on unseen data.
#
# 16. [Lesson Review](https://www.youtube.com/watch?v=4P1XFPRsSLY)
