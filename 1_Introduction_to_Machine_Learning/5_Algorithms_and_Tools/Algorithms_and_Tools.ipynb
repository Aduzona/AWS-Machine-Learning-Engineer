# %% [markdown]
# # Algorithms and Tools
#
# In this lesson you'll train, test, and optimize on liner, tree-based, XGBoost, and AutoGluon Tabular models. And you will also create a model using SageMaker Jumpstart.

# %% [markdown]
# 1. [Introduction](https://www.youtube.com/watch?v=L-o6a37eKmA)
# 2. [Lesson_Outline](https://www.youtube.com/watch?v=a1Dv7HyhZZA)
# 3. [How Do Experts Think About Algorithms and Tools?](https://www.youtube.com/watch?v=iYwtj9LlDoo)
#
#
# 4. [Linear Models](https://www.youtube.com/watch?v=gbWBJbiw2Y8)
#
# **QUESTION 1 OF 2**
#
# Linear models can be used to solve which type of machine learning problem?
# - Regression and Classification
#
# **QUESTION 2 OF 2**
#
# Consider the following scenario:
#
# You are a newly hired Machine Learning Engineer working at a prominent ride-sharing company, Rides Rides Rides. Your product manager tasked you with coming up with a new baseline model to predict the number of expected rides booked each day for the next 30 days. They provide you with a year's worth of previous data to build your predictive model. You decide to build a linear regression model first. What reason would you give to your product manager for choosing a linear regression model over their request to build a super sophisticated deep learning model?
#
# - Linear regression can be easily modeled and interpreted. If the model performs well, the overall cost of development and deployment will be low.
#
#
# 5. [Solution: Linear Models](https://www.youtube.com/watch?v=MgyAgREWriw)
#
# SGD= Stochastic Gradient Descent.
#
# [templates to use in Sagemaker](https://github.com/udacity/nd009t-c1-intro-to-ml-templates.git)
#
#
# **Quiz Question**
#
# In this exercise, we used the train dataset to train our model and the test dataset to evaluate it. What could we have done instead?
#
# - Used a validation dataset to optimize our model. Then used the test dataset as before to evaluate.
#   - But since we were not really focused on optimizing our model, it is ok to just use a train and test dataset.
#
#
# 6. [Tree Based Models](https://www.youtube.com/watch?v=w1YdmitawqQ)
# 7. [XGBoost](https://www.youtube.com/watch?v=mZeL3xxsT54)
# 8. Quiz: XGBoost
#
# The XGBoost parameter list is extensive, which allows greater control in performance but is overwhelming to start on as your first approach.
#
# **QUESTION 2 OF 2**
#
# Have a look at the python code below:
#
# ```py
# dtrain = xgb.DMatrix(df_train_features, label=df_train_target)
# param = {"max_depth": 10, "eta": 1, "objective": "multi:softmax", "num_class": 5}
# num_round = 100
# bst = xgb.train(param, dtrain, num_round)
# ```
#    - Multiclass classification
#      - Softmax is a method used for classifying more than 2 classes in a dataset.
#
#
# 9.  [Solution:XGBoost](https://www.youtube.com/watch?v=X0fkqhSkfVM)
#
#
#
# 10. [AutoGluon](https://www.youtube.com/watch?v=g293wbgGiRA)
# 11. [Quiz:AutoGluon]
#
# In AutoGluon,  If you are not worried about inference speed or storage size,best_quality will produce the best performing model.
#
# 12. [Solution: AutoGluon](https://www.youtube.com/watch?v=nSaKA5uCuC8)
# 13.
