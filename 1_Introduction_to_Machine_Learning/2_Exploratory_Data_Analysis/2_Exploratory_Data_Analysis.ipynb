# %% [markdown]
# # Exploratory Data Analysis
#
# 1. [Introduction](https://www.youtube.com/watch?v=xhbgu0-_vwo)
# 2. [Lesson Outline](https://www.youtube.com/watch?v=LTnAjXkZ2xs)
# 3. [How Do Experts Think About Exploratory Data Analysis?](https://www.youtube.com/watch?v=_ssqvDGKK3c)
# 4. [Intro to Amazon Sagemaker](https://www.youtube.com/watch?v=kaz-Ig7F9go)
#
# * S3 - Storage(Object storage (dataset files, model assets, etc).)
# * SageMaker - Machine learning(Tools from AWS that empowers users to create machine learning models.)
# * SageMaker Studio - IDE(A cloud based IDE for data science and machine learning.)
# * Ground Truth - Annotation(Service that annotates datasets through mechanical turk, private entities, or a vendor.)
# * Data Wrangler - EDA(Prepares data for downstream ML tasks.)
#
# 5. [Sagemaker Studio](https://www.youtube.com/watch?v=9lciIcw4RVQ)
# 6. [DataFrames](https://www.youtube.com/watch?v=yNpkfdxfeGg&t=13s)
#
# If 2 features are strongly correlated, we can often remove one as it provides similar information gain for a model.
# Bacause using both features will not improve our accuracy, so remove one feature.
#
# 7. [Solution: Sagemaker Studio](https://www.youtube.com/watch?time_continue=2&v=E21RkWHvJNg&feature=emb_logo)
#
# When doing EDA, it's always a good idea to do which of the following?
# * Table Summary of the features
# * Histogram of the features
# * Correlation Matrix
#
# 8. [Data Wrangler](https://www.youtube.com/watch?v=HG0BDe3W2LI)
#
# * [S3 Upload](https://www.youtube.com/watch?v=vopw2WtTDgc)
# * [Data Wrangler: Pipeline Creation](https://www.youtube.com/watch?v=DgkXsWDVlXk)
# * [Data Wrangler: Pipeline Export](https://www.youtube.com/watch?v=2Y1Pb2EUT_Y)
#
# 9.  [Quiz: Data Wrangler]
#
# Your company XYZ Inc has sales metrics for several clients' restaurants. The client sends over a CSV file from each restaurant with data that has a header file of name,food_item,date_of_sale,item_cost.
#
# Types are:
#
# * name: string
# * food_item: string
# * date_of_sale: date type, example 2021-01-01
# * item_cost: float
#
# After combining the data together, you are asked to take the combined dataset and transform some of the fields into additional data points.
#
# * What are the transformations you can do with the data provided?
#   * Transform the date_of_sale field into separate month,day and hour fields.
#   * Transform the food_item field with one-hot encoding
#   * Normalize the item_cost field.
# * Data summary tables often provide a range of values for each feature in your dataset. These may include but are not limited to: min and max values, mean, median, standard deviation, and quantiles. Select an outcome that could happen based on a data summary table.
#   * Sometimes if you see min or max values that are in extreme ranges from the mean, there may be a few data points that are outliers.
# 10. [Solution: Data Wrangler](https://www.youtube.com/watch?v=0EpR1fr6FHU)
#
# In this exercise, we applied a histogram and table summary visualization to our dataset. But this isn't the only visualization we could have applied to the data.
#
# Which of the following were other options? Select all that apply.
# * Bias Report
# * Quick Model
# * Scatter Plot
# * Target Leakage
#
# 11. [Ground Truth](https://www.youtube.com/watch?v=r71zlaUtr4s)
#
# * [Annotation Creation](https://www.youtube.com/watch?v=pSX3gCKyOpU)
# * [Inviting Workers](https://www.youtube.com/watch?v=L5Kz59OukGQ)
# * [Annotation Job](https://www.youtube.com/watch?v=WfrU4HUoj1M)
#
# 12. [Quiz_Ground_Truth]
#
# **QUESTION 1 OF 3**
#
# What type of task would you create to solve this data labeling issue?
#
# Company XYZ Co. ships different types of containers all across the world, and would like to know how many are moved onto ships every hour. They have thousands of hours of video each day from workers loading the containers but need annotators to label which container is which in the video. They can use this data to eventually train a model to identify them automatically.
#
# * Video object detection
#
# **QUESTION 2 OF 3**
#
# What are some of the benefits of using Ground Truth for annotating your dataset?
# * Ability to create a pipeline for labelling your data of text, images, and video.
#
# * Reduce annotation costs by assisting human annotators using automatic data labeling through AWS.
#
# * Use mechanical turk, private, or vendors to source the annotation jobs.
#
# **Why Annotate? 3 of 3**
#
# Why do we annotate data? Write down a few sentences on why it is so important for training models.
#
# *Your reflection*
#
# We annotate data so that we can create a model that can associate labels with given features it sees. The annotated data provides experience for the model.
#
# *Things to think about*
#
# Awesome job! Any answer will do, but mainly driving home the fact that without highly accurate labeled data, models will perform subpar if not terribly on real-world data.
#
# 13. [Solution: Ground Truth](https://www.youtube.com/watch?v=aH3hIpK-gUI)
# 14. [When To Use Exploratory Data Analysis](https://www.youtube.com/watch?v=0aMFA5YHN6c)
# 15. [Solution: Analyzing the Iris Dataset](https://www.youtube.com/watch?v=O0xxAHivUTs)
# 16. [Lesson Review](https://www.youtube.com/watch?v=HrW8UW5N2_8)

# %%
# !wget https://raw.githubusercontent.com/udacity/nd009t-c1-intro-to-ml-templates/master/exploratory-data-analysis/concept3_ground_truth/starter/sentiment_data.jsonl
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
