# %% [markdown]
# 1. [Introduction](https://www.youtube.com/watch?v=T7qwnEBgi28)
# 2. [Lesson Outline](https://www.youtube.com/watch?v=HO5ISeqZvKA)
# 3. [Experts_on_ML_Concepts](https://www.youtube.com/watch?v=_UN4pgUNzwk)
#
#
# **QUIZ QUESTION**
#
# * Why is it important to have a general understanding of most of the machine learning concepts?
#   * Yes! Expertise in tool usage isn't the end all be all, it is good to understand what tools are out there so that if you need it you can quickly expand your knowledge for the problem you are trying to solve.
#
# 4. [Domain, Model, and Data](https://www.youtube.com/watch?v=gQ0OlmcBWYE)
# 5. [Quiz_Domain, Model, and Data]
#
# * From the description below, which of the answers best describes the next task?
#
# Julia was tasked to write an analytical report for a new client. Before she started looking at the data, she requested a detailed profile of the new client. This allows Julia to better apply her knowledge to the problem at hand.
#   * It is best practice to understand where the data came from in order to understand the domain of the problem and define solutions that optimize for it.
#
# * These 3 are examples of data in the domain, data, model paradigm
#   *  Features
#   *  Data Types
#   *  Database
#
# 6. [ML Lifecycle](https://www.youtube.com/watch?v=ntiZ-Dh7-No)
# 7. Supervised and Unsupervised ML
# * [Supervised ML](https://www.youtube.com/watch?v=jnX9-uQsTV8)

# %%
from sklearn.linear_model import LinearRegression

features = [[5, 3.4, 6], [1, 0.4, 10], [2, 0.1, 1]]
target = [1.4, 0.5, 1]

reg = LinearRegression().fit(features, target)

# Score model with features and target
print(reg.score(features, target))
# Predict new values based on features
print(reg.predict(features))
# Out:
# 1.0
# [1.4 0.5 1. ]

# %% [markdown]
# * [Unsupervised ML](https://www.youtube.com/watch?v=bTcdTuSjoY0)

# %%
from sklearn.cluster import KMeans

features = [[5, 3.4, 6], [1, 0.4, 10], [2, 0.1, 1]]
# Cluster into 3 groups
kmeans = KMeans(n_clusters=3).fit(features)

# Prints which data point belongs to which cluster group
print(kmeans.labels_)
# Prints the metric of how clustering performed
print(kmeans.inertia_)
# Out:
# [2 1 0]
# 0.0

# %% [markdown]
# 8. [Quiz_Supervised_and_Unsupervised_ML]
#
# * K-means clustering is a good tool to build an unsupervised representation of the data so you can better understand the relationships between values. Although we are not predicting anything, we can clearly see these relationship in the plot.
#
# 9.  Regression and Classification ML
#
# * [Regression](https://www.youtube.com/watch?v=QTyR3bjfHmU)
# * [Classification](https://www.youtube.com/watch?v=bL_iBTrtLS8)
#
# 10. [Solution: Regression and Classification ML](https://www.youtube.com/watch?v=SjLTVu920Wg)
#
# * In the exercise, we converted the regression values into rounded integers. Why did we do this?
#   - Because the iris dataset is actually a classification problem, and evaluating a regression model on a classification problem will not provide an accurate score. However, you can make it a classification type of problem if you transform the regression values into classification values.
#     - Even though regression and classification are different, we can modify the output of each to fit into the other model form.
#
#
#
#
# 11. [When To Use Machine Learning](https://www.youtube.com/watch?v=uVreneJRWig)
# 12. [Solution: ML Lifecycle Case Study](https://www.youtube.com/watch?v=AoKtGcozvZo)
# 13. [Lesson Review](https://www.youtube.com/watch?v=10u94IYXONg)
