# %% [markdown]
# 1. Course Overview
# 2. Lesson_Overview
# 3. What You'll Build
# 4. Introduction to Machine learning Engineering
# 5. Prerequisites
# 6. Business Stakeholders
# 7. History of Machine Learning Engineering
# 8. When to Use Machine Learning Engineering
# 9. Tools and Environment
# 10. Quiz:
#
# What are the key concerns of a Machine Learning Engineer?
#
# - Helping data professionals such as Data Scientists make their work "production ready"
# - Deploying APIs
# - Automating workflows
# - Monitoring
#
#
# 11. []
